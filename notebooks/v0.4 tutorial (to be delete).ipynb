# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
# %matplotlib inline
import torch
from deepseries.models import WaveNet
from deepseries.dataset import Property, TimeSeries, SeriesFrame
from deepseries.train import Learner
from torch.optim import Adam
from torch import nn
import matplotlib as mpl
from sklearn.metrics import mean_absolute_error

info = pd.read_excel("./data/info.xlsx")
recored = info.set_index("contributor_id")['huangzf']
info = pd.read_excel("./data/info.xlsx").set_index("contributor_id")[['pjt_name', 'pjt_type']]

# %%
power = pd.read_csv('./data/power.csv', parse_dates=['data_time'])[['data_time', 'cid', 'value']]
power = power.set_index("data_time").groupby("cid").resample("1H").sum().reset_index()
power = power.pivot(index='cid', columns='data_time', values='value')
power = power.apply(np.log1p)

# %%
class Test:
    
    def __init__(self, x=False):
        self.x = x

# %%
test1 = Test()
test2 = Test(True)
test3 = Test()

# %%
test1.x
# Out:
# False

# %%
test3.x
# Out:
# False

# %%
import torch

# %%
bn = torch.nn.BatchNorm1d(4)

# %%
x = torch.rand(4, 4, 2)

# %%
x
# Out:
# tensor([[[0.5313, 0.7270],
#          [0.8149, 0.9874],
#          [0.8993, 0.8537],
#          [0.5373, 0.8479]],
#
#         [[0.9211, 0.5612],
#          [0.5480, 0.3970],
#          [0.7975, 0.5153],
#          [0.8670, 0.9243]],
#
#         [[0.3176, 0.5565],
#          [0.3975, 0.6870],
#          [0.7716, 0.5864],
#          [0.9704, 0.9500]],
#
#         [[0.2999, 0.5589],
#          [0.0517, 0.1735],
#          [0.0156, 0.9910],
#          [0.2423, 0.3212]]])

# %%
bn(x).sum(dim=0)
# Out:
# tensor([[-0.8827,  0.8827],
#         [-0.7302,  0.7302],
#         [-0.7965,  0.7965],
#         [-0.7692,  0.7692]], grad_fn=<SumBackward1>)

# %%
bn(x).sum(dim=0).sum(dim=1)
# Out:
# tensor([ 5.9605e-07,  1.7881e-07, -5.3644e-07,  8.3447e-07],
#        grad_fn=<SumBackward1>)

# %%
x.shape
# Out:
# torch.Size([4, 4, 2])

# %%
x.std(dim=0)
# Out:
# tensor([0.3067, 0.3502, 0.1457, 0.1209])

# %%
is_zero = power.values == 0
is_nan = power.isnull().values
is_valid = ~is_zero & ~is_nan

xy = np.ma.masked_array(power.values, mask=~is_valid)

series_mu = xy.mean(axis=1).data.reshape(-1, 1)
series_std = xy.std(axis=1).data.reshape(-1, 1)
xy = (xy - series_mu) / series_std
xy = xy.filled(0.)

xy = np.expand_dims(xy, 1).astype('float32')

N_TEST = 24 * 15
N_VALID = 24 * 15
DROP_ZERO = True
DEC_LEN = 24 * 2
ENC_LEN = 24 * 7
time_free_space = 24

# %%
def n_lag(series, n):
    lag = np.zeros_like(series)
    lag[:, :, n:] = series[:, :, :-n]
    return lag

x_lag7 = n_lag(xy, 7)
x_lag14 = n_lag(xy, 14)

x_is_valid = np.expand_dims(is_valid, 1)

x_num_features = np.concatenate([x_lag7, x_lag14], axis=1).astype("float32")

# %%
def periodic_feature(x, T):
    psin = np.sin(x * np.pi * 2 / T)
    pcos = np.cos(x * np.pi * 2 / T)
    return np.stack([psin, pcos], axis=0)


xy_weekday = np.repeat(
    np.expand_dims(
        periodic_feature(power.columns.weekday.values, 7), axis=0), xy.shape[0], axis=0)

xy_hour = np.repeat(
    np.expand_dims(
        periodic_feature(power.columns.hour.values, 24), axis=0), xy.shape[0], axis=0)

xy_month = np.repeat(
    np.expand_dims(
        periodic_feature(power.columns.month.values, 12), axis=0), xy.shape[0], axis=0)

xy_num_features = np.concatenate([
    xy_weekday,
    xy_hour,
    xy_month,
    x_is_valid
], axis=1).astype('float32')

# %%
class ForwardSpliter:
    
    def split(self, time_idx, enc_len, dec_len, valid_size):
        if valid_size < 1:
            valid_size = int(np.floor(len(time_idx) * valid_size))
        valid_idx = time_idx[-(valid_size+enc_len):]
        train_idx = time_idx[:-valid_size]
        return train_idx, valid_idx
    
spliter = ForwardSpliter()
train_idx, valid_idx = spliter.split(np.arange(xy.shape[2]), ENC_LEN, DEC_LEN, N_TEST+N_VALID)
valid_idx, test_idx = spliter.split(valid_idx, ENC_LEN, DEC_LEN, N_VALID)

train_xy = TimeSeries(xy[:, :, train_idx])
valid_xy = TimeSeries(xy[:, :, valid_idx])

train_xy_features = TimeSeries(xy_num_features[:, :, train_idx])
valid_xy_features = TimeSeries(xy_num_features[:, :, valid_idx])

train_x_features = TimeSeries(x_num_features[:, :, train_idx])
valid_x_features = TimeSeries(x_num_features[:, :, valid_idx])

train_frame = SeriesFrame(train_xy, batch_size=4, enc_lens=ENC_LEN, dec_lens=DEC_LEN, 
                          enc_num_feats=[train_xy_features, train_x_features], dec_num_feats=[train_xy_features])
valid_frame = SeriesFrame(valid_xy, batch_size=4, enc_lens=ENC_LEN, dec_lens=DEC_LEN,
                         enc_num_feats=[valid_xy_features, valid_x_features], dec_num_feats=[valid_xy_features])

test_xy = xy[:, :, test_idx]
test_xf = np.concatenate([xy_num_features[:, :, test_idx], x_num_features[:, :, test_idx]], axis=1)
test_yf = xy_num_features[:, :, test_idx]

# %%
model = WaveNet()
opt = Adam(model.parameters(), 0.001)
loss_fn = nn.MSELoss()
# model.cuda()
learner = Learner(model, opt, loss_fn, './power_env', log_interval=20)
learner.fit(500, train_frame, valid_frame, patient=30, start_save=50)
# Out:
# epoch 1 / 500, batch 100%, train_loss 0.4763, valid loss 0.6258
# epoch 2 / 500, batch 100%, train_loss 1.6231, valid loss 0.6683
# epoch 3 / 500, batch 100%, train_loss 0.4188, valid loss 0.6473
# epoch 4 / 500, batch  17%, train loss 0.6854
# epoch 4 / 500, batch 100%, train_loss 0.7401, valid loss 0.8250
# epoch 5 / 500, batch 100%, train_loss 1.0654, valid loss 0.5804
# epoch 6 / 500, batch 100%, train_loss 0.2585, valid loss 0.5983
# epoch 7 / 500, batch  50%, train loss 0.1205
# epoch 7 / 500, batch 100%, train_loss 0.0816, valid loss 0.5271
# epoch 8 / 500, batch 100%, train_loss 0.5227, valid loss 0.5850
# epoch 9 / 500, batch 100%, train_loss 0.4562, valid loss 0.5693
# epoch 10 / 500, batch  83%, train loss 0.0857
# epoch 10 / 500, batch 100%, train_loss 0.0857, valid loss 0.5957
# epoch 11 / 500, batch 100%, train_loss 0.1915, valid loss 0.7323
# epoch 12 / 500, batch 100%, train_loss 0.2391, valid loss 0.6973
# epoch 13 / 500, batch 100%, train_loss 0.2031, valid loss 0.4263
# epoch 14 / 500, batch  17%, train loss 0.2082
# epoch 14 / 500, batch 100%, train_loss 0.1664, valid loss 0.3780
# epoch 15 / 500, batch 100%, train_loss 0.2563, valid loss 0.5747
# epoch 16 / 500, batch 100%, train_loss 0.1465, valid loss 0.3165
# epoch 17 / 500, batch  50%, train loss 0.1801
# epoch 17 / 500, batch 100%, train_loss 0.1545, valid loss 0.4188
# epoch 18 / 500, batch 100%, train_loss 0.3822, valid loss 0.5333
# epoch 19 / 500, batch 100%, train_loss 0.1862, valid loss 0.2865
# epoch 20 / 500, batch  83%, train loss 0.0963
# epoch 20 / 500, batch 100%, train_loss 0.0963, valid loss 0.2111
# epoch 21 / 500, batch 100%, train_loss 0.1033, valid loss 0.2687
# epoch 22 / 500, batch 100%, train_loss 0.1699, valid loss 0.1514
# epoch 23 / 500, batch 100%, train_loss 0.1538, valid loss 0.2052
# epoch 24 / 500, batch  17%, train loss 0.0486
# epoch 24 / 500, batch 100%, train_loss 0.0903, valid loss 0.1872
# epoch 25 / 500, batch 100%, train_loss 0.0649, valid loss 0.3102
# epoch 26 / 500, batch 100%, train_loss 0.1851, valid loss 0.3836
# epoch 27 / 500, batch  50%, train loss 0.0925
# epoch 27 / 500, batch 100%, train_loss 0.0778, valid loss 0.1845
# epoch 28 / 500, batch 100%, train_loss 0.7141, valid loss 0.2329
# epoch 29 / 500, batch 100%, train_loss 0.2840, valid loss 0.4712
# epoch 30 / 500, batch  83%, train loss 0.3282
# epoch 30 / 500, batch 100%, train_loss 0.3282, valid loss 0.1904
# epoch 31 / 500, batch 100%, train_loss 0.0581, valid loss 0.1905
# epoch 32 / 500, batch 100%, train_loss 0.1019, valid loss 0.3285
# epoch 33 / 500, batch 100%, train_loss 0.1100, valid loss 0.2342
# epoch 34 / 500, batch  17%, train loss 0.0254
# epoch 34 / 500, batch 100%, train_loss 0.3128, valid loss 0.2871
# epoch 35 / 500, batch 100%, train_loss 0.8338, valid loss 0.1973
# epoch 36 / 500, batch 100%, train_loss 0.1033, valid loss 0.1591
# epoch 37 / 500, batch  50%, train loss 0.0469
# epoch 37 / 500, batch 100%, train_loss 0.1114, valid loss 0.2150
# epoch 38 / 500, batch 100%, train_loss 0.1869, valid loss 0.4273
# epoch 39 / 500, batch 100%, train_loss 0.1821, valid loss 0.1499
# epoch 40 / 500, batch  83%, train loss 0.0886
# epoch 40 / 500, batch 100%, train_loss 0.0886, valid loss 0.2360
# epoch 41 / 500, batch 100%, train_loss 0.0932, valid loss 0.2000
# epoch 42 / 500, batch 100%, train_loss 0.1020, valid loss 0.1550
# epoch 43 / 500, batch 100%, train_loss 0.0392, valid loss 0.1266
# epoch 44 / 500, batch  17%, train loss 0.2246
# epoch 44 / 500, batch 100%, train_loss 0.1192, valid loss 0.1280
# epoch 45 / 500, batch 100%, train_loss 0.4970, valid loss 0.2771
# epoch 46 / 500, batch 100%, train_loss 0.3033, valid loss 0.3987
# epoch 47 / 500, batch  50%, train loss 0.3621
# epoch 47 / 500, batch 100%, train_loss 0.4880, valid loss 0.2026
# epoch 48 / 500, batch 100%, train_loss 0.2577, valid loss 0.2922
# epoch 49 / 500, batch 100%, train_loss 0.1040, valid loss 0.2677
# epoch 50 / 500, batch  83%, train loss 0.1552
# epoch 50 / 500, batch 100%, train_loss 0.1552, valid loss 0.3400
# epoch 51 / 500, batch 100%, train_loss 0.3664, valid loss 0.4107
# epoch 52 / 500, batch 100%, train_loss 0.5357, valid loss 0.2398
# epoch 53 / 500, batch 100%, train_loss 0.1291, valid loss 0.1712
# epoch 54 / 500, batch  17%, train loss 0.8966
# epoch 54 / 500, batch 100%, train_loss 0.3290, valid loss 0.2083
# epoch 55 / 500, batch 100%, train_loss 0.0649, valid loss 0.1179
# epoch 56 / 500, batch 100%, train_loss 0.1091, valid loss 0.1937
# epoch 57 / 500, batch  50%, train loss 0.0609
# epoch 57 / 500, batch 100%, train_loss 0.0587, valid loss 0.1901
# epoch 58 / 500, batch 100%, train_loss 0.2228, valid loss 0.1264
# epoch 59 / 500, batch 100%, train_loss 0.1428, valid loss 0.1774
# epoch 60 / 500, batch  83%, train loss 0.0956
# epoch 60 / 500, batch 100%, train_loss 0.0956, valid loss 0.1885
# epoch 61 / 500, batch 100%, train_loss 0.5908, valid loss 0.2937
# epoch 62 / 500, batch 100%, train_loss 0.0305, valid loss 0.2138
# epoch 63 / 500, batch 100%, train_loss 0.1427, valid loss 0.3026
# epoch 64 / 500, batch  17%, train loss 0.0304
# epoch 64 / 500, batch 100%, train_loss 0.0475, valid loss 0.2693
# epoch 65 / 500, batch 100%, train_loss 0.0621, valid loss 0.3428
# epoch 66 / 500, batch 100%, train_loss 0.0457, valid loss 0.2617
# epoch 67 / 500, batch  50%, train loss 0.0532
# epoch 67 / 500, batch 100%, train_loss 0.0519, valid loss 0.2345
# epoch 68 / 500, batch 100%, train_loss 0.0775, valid loss 0.3688
# epoch 69 / 500, batch 100%, train_loss 0.1140, valid loss 0.3172
# epoch 70 / 500, batch  83%, train loss 0.0953
# epoch 70 / 500, batch 100%, train_loss 0.0953, valid loss 0.2220
# epoch 71 / 500, batch 100%, train_loss 0.1164, valid loss 0.1097
# epoch 72 / 500, batch 100%, train_loss 0.0479, valid loss 0.1571
# epoch 73 / 500, batch 100%, train_loss 1.0343, valid loss 0.2691
# epoch 74 / 500, batch  17%, train loss 0.0783
# epoch 74 / 500, batch 100%, train_loss 0.1832, valid loss 0.2481
# epoch 75 / 500, batch 100%, train_loss 0.1217, valid loss 0.2628
# epoch 76 / 500, batch 100%, train_loss 0.4069, valid loss 0.2149
# epoch 77 / 500, batch  50%, train loss 0.0667
# epoch 77 / 500, batch 100%, train_loss 0.0454, valid loss 0.2209
# epoch 78 / 500, batch 100%, train_loss 0.1755, valid loss 0.1393
# epoch 79 / 500, batch 100%, train_loss 0.1314, valid loss 0.1418
# epoch 80 / 500, batch  83%, train loss 0.4478
# epoch 80 / 500, batch 100%, train_loss 0.4478, valid loss 0.2125
# epoch 81 / 500, batch 100%, train_loss 0.1049, valid loss 0.2885
# epoch 82 / 500, batch 100%, train_loss 0.0736, valid loss 0.2051
# epoch 83 / 500, batch 100%, train_loss 0.0170, valid loss 0.2104
# epoch 84 / 500, batch  17%, train loss 0.0020
# epoch 84 / 500, batch 100%, train_loss 0.1066, valid loss 0.1707
# epoch 85 / 500, batch 100%, train_loss 0.1516, valid loss 0.1618
# epoch 86 / 500, batch 100%, train_loss 0.1456, valid loss 0.3521
# epoch 87 / 500, batch  50%, train loss 0.3531
# epoch 87 / 500, batch 100%, train_loss 0.2387, valid loss 0.1025
# epoch 88 / 500, batch 100%, train_loss 0.0372, valid loss 0.1052
# epoch 89 / 500, batch 100%, train_loss 0.1193, valid loss 0.1353
# epoch 90 / 500, batch  83%, train loss 0.1604
# epoch 90 / 500, batch 100%, train_loss 0.1604, valid loss 0.2509
# epoch 91 / 500, batch 100%, train_loss 0.2735, valid loss 0.2236
# epoch 92 / 500, batch 100%, train_loss 0.1699, valid loss 0.1388
# epoch 93 / 500, batch 100%, train_loss 0.0421, valid loss 0.1190
# epoch 94 / 500, batch  17%, train loss 0.1558
# epoch 94 / 500, batch 100%, train_loss 0.2298, valid loss 0.2464
# epoch 95 / 500, batch 100%, train_loss 0.9528, valid loss 0.3982
# epoch 96 / 500, batch 100%, train_loss 0.1244, valid loss 0.2859
# epoch 97 / 500, batch  50%, train loss 0.2393
# epoch 97 / 500, batch 100%, train_loss 0.2087, valid loss 0.1022
# epoch 98 / 500, batch 100%, train_loss 0.0870, valid loss 0.1686
# epoch 99 / 500, batch 100%, train_loss 0.2080, valid loss 0.1668
# epoch 100 / 500, batch  83%, train loss 0.0704
# epoch 100 / 500, batch 100%, train_loss 0.0704, valid loss 0.1774
# epoch 101 / 500, batch 100%, train_loss 0.2558, valid loss 0.1542
# epoch 102 / 500, batch 100%, train_loss 0.1359, valid loss 0.3833
# epoch 103 / 500, batch 100%, train_loss 0.4513, valid loss 0.0971
# epoch 104 / 500, batch  17%, train loss 0.1855
# epoch 104 / 500, batch 100%, train_loss 0.6963, valid loss 0.2540
# epoch 105 / 500, batch 100%, train_loss 0.1243, valid loss 0.2993
# epoch 106 / 500, batch 100%, train_loss 0.1635, valid loss 0.2267
# epoch 107 / 500, batch  50%, train loss 0.2089
# epoch 107 / 500, batch 100%, train_loss 0.2550, valid loss 0.2841
# epoch 108 / 500, batch 100%, train_loss 0.1988, valid loss 0.2265
# epoch 109 / 500, batch 100%, train_loss 0.1273, valid loss 0.1468
# epoch 110 / 500, batch  83%, train loss 0.1489
# epoch 110 / 500, batch 100%, train_loss 0.1489, valid loss 0.0843
# epoch 111 / 500, batch 100%, train_loss 0.1065, valid loss 0.2915
# epoch 112 / 500, batch 100%, train_loss 0.0696, valid loss 0.5112
# epoch 113 / 500, batch 100%, train_loss 0.0466, valid loss 0.1654
# epoch 114 / 500, batch  17%, train loss 0.2065
# epoch 114 / 500, batch 100%, train_loss 0.1861, valid loss 0.1304
# epoch 115 / 500, batch 100%, train_loss 0.3092, valid loss 0.3801
# epoch 116 / 500, batch 100%, train_loss 0.0288, valid loss 0.1802
# epoch 117 / 500, batch  50%, train loss 0.2719
# epoch 117 / 500, batch 100%, train_loss 0.1837, valid loss 0.2270
# epoch 118 / 500, batch 100%, train_loss 0.1136, valid loss 0.1751
# epoch 119 / 500, batch 100%, train_loss 0.1916, valid loss 0.1527
# epoch 120 / 500, batch  83%, train loss 0.1059
# epoch 120 / 500, batch 100%, train_loss 0.1059, valid loss 0.1291
# epoch 121 / 500, batch 100%, train_loss 0.1930, valid loss 0.1408
# epoch 122 / 500, batch 100%, train_loss 0.0952, valid loss 0.2367
# epoch 123 / 500, batch 100%, train_loss 0.4421, valid loss 0.1540
# epoch 124 / 500, batch  17%, train loss 0.1265
# epoch 124 / 500, batch 100%, train_loss 0.1077, valid loss 0.1466
# epoch 125 / 500, batch 100%, train_loss 0.0757, valid loss 0.1704
# epoch 126 / 500, batch 100%, train_loss 0.0417, valid loss 0.1580
# epoch 127 / 500, batch  50%, train loss 0.0156
# epoch 127 / 500, batch 100%, train_loss 0.0404, valid loss 0.2481
# epoch 128 / 500, batch 100%, train_loss 0.5632, valid loss 0.1235
# epoch 129 / 500, batch 100%, train_loss 0.0083, valid loss 0.2410
# epoch 130 / 500, batch  83%, train loss 0.1489
# epoch 130 / 500, batch 100%, train_loss 0.1489, valid loss 0.2545
# epoch 131 / 500, batch 100%, train_loss 0.0969, valid loss 0.2199
# epoch 132 / 500, batch 100%, train_loss 0.0939, valid loss 0.3018
# epoch 133 / 500, batch 100%, train_loss 0.2450, valid loss 0.3201
# epoch 134 / 500, batch  17%, train loss 0.1374
# epoch 134 / 500, batch 100%, train_loss 0.5413, valid loss 0.2031
# epoch 135 / 500, batch 100%, train_loss 0.0758, valid loss 0.2212
# epoch 136 / 500, batch 100%, train_loss 0.1835, valid loss 0.2902
# epoch 137 / 500, batch  50%, train loss 0.0525
# epoch 137 / 500, batch 100%, train_loss 0.0471, valid loss 0.2828
# epoch 138 / 500, batch 100%, train_loss 0.0178, valid loss 0.2210
# epoch 139 / 500, batch 100%, train_loss 0.0588, valid loss 0.2041
# epoch 140 / 500, batch  83%, train loss 0.3993
# epoch 140 / 500, batch 100%, train_loss 0.3993, valid loss 0.1557
# early stopping!
# training finished, best epoch 109, best valid loss 0.0843

# %%
test_xy = torch.as_tensor(xy[:, :, test_idx]).cuda()
test_xf = torch.as_tensor(np.concatenate([xy_num_features[:, :, test_idx], x_num_features[:, :, test_idx]], axis=1)).cuda()
test_yf = torch.as_tensor(xy_num_features[:, :, test_idx]).cuda()

# %%
def plot(x_true, y_true, y_pred):
    enc_ticks = np.arange(x_true.shape[1])
    dec_ticks = np.arange(y_pred.shape[1]) + x_true.shape[1]
    for idx, name in enumerate(power.index):
        plt.figure(figsize=(12, 3))
        plt.plot(enc_ticks, x_true[idx])
        plt.plot(dec_ticks, y_pred[idx], label='pred')
        plt.plot(dec_ticks, y_true[idx], label='true')
        plt.title(name)
        plt.legend()

def wmape(y_hat, y):
    scores = []
    for day in range(int(y.shape[0] / 24)):
        scores.append(np.abs(y[day*24: (day+1)*24] - y_hat[day*24: (day+1)*24]).sum() / np.sum(y[day*24: (day+1)*24]))
    return scores

def metric(y_true, y_pred):
    scores = {}
    for idx, name in enumerate(power.index):
        scores[name] = wmape(y_pred[idx], y_true[idx])
    return pd.DataFrame(scores)

def predict(learner, xy, x_feats, y_feats, epoch):
    learner.load(f"/home/zhouzr/project/Deep-Time-Series-Prediction/power_env/checkpoints/model-epoch-{epoch}.pkl")
    learner.model.eval()
    learner.model.cuda()
    preds = []
    days = int(xy.shape[2] / 24) - 9 + 1
    for day in range(days):
        step = day * 24
#         enc_start = day
#         enc_end = (step+ENC_LEN) / 24
#         dec_start = enc_end
#         dec_end = (step+ENC_LEN+DEC_LEN) / 24
#         print(f"start {enc_start}, end {int(dec_end)}" )
        
        step_pred = model.predict(
            xy[:, :, step: step+ENC_LEN], 
            enc_num=x_feats[:, :, step: step+ENC_LEN],
            dec_num=y_feats[:, :, step+ENC_LEN: step+ENC_LEN+DEC_LEN], dec_len=48).cpu().detach().numpy()
        if step == 0:
            preds.append(step_pred)
        else:
            preds.append(step_pred[:, :, -24:])
    preds = np.concatenate(preds, axis=2)
    preds = np.expm1(preds.squeeze() * series_std + series_mu)
    
    x_true = np.expm1(xy[:, :, :ENC_LEN].cpu().numpy().squeeze() * series_std + series_mu)
    y_true = np.expm1(xy[:, :, ENC_LEN:].cpu().numpy().squeeze() * series_std + series_mu)
    
    return x_true, y_true, preds

# %%
x_true, y_true, y_pred  = predict(learner, test_xy, test_xf, test_yf, 109)
scores = pd.DataFrame([metric(y_true, y_pred).mean().rename("wave"), recored.rename("normal")]).T.dropna()

# %%
scores.merge(info, left_index=True, right_index=True)
# Out:
#                                       wave    normal  \
# 91E0B6DC00B91783E0530BC8100A0E30  0.225327  1.393969
# 91E0B6DC00BC1783E0530BC8100A0E30  0.370441  0.425888
# 91E0B6DC00C91783E0530BC8100A0E30  0.216851  0.131399
# 91E0B6DC00CB1783E0530BC8100A0E30  0.256917  0.079528
# 91E0B6DC00DA1783E0530BC8100A0E30  0.287358  0.143502
# 91E0B6DC00E31783E0530BC8100A0E30  0.321122  3.283425
# 91E0B6DC00E91783E0530BC8100A0E30  0.028815  0.042607
# 91E0B6DC01081783E0530BC8100A0E30  0.250387  0.848073
# 91E0B6DC01171783E0530BC8100A0E30  0.101186  0.192005
# 91E0B6DC01221783E0530BC8100A0E30  0.202223  0.811921
# 91E0B6DC013E1783E0530BC8100A0E30  1.353689  3.593963
# 91E0C8BAA12E259EE0530BC8100AFFB2  1.484132  2.572387
